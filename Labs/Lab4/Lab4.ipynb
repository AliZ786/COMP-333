# %%
# Mohammad Ali Zahir
# ID: 400767619
# COMP 333 - Lab 4

# %%
# Using this command to install librairies

# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install plotnine
# Out:
# ...
#      ---------------------------------------- 1.2/1.2 MB 26.7 MB/s eta 0:00:00
# ...
#      --------------------------------------- 42.5/42.5 MB 59.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 9.2/9.2 MB 97.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 233.8/233.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 64.7/64.7 kB 3.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 111.8/111.8 kB 6.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 340.1/340.1 kB 20.6 MB/s eta 0:00:00
# ...

# %%
# import the required modules

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset into the required file

surveys_df = pd.read_csv("./surveys.csv")

# Print the specific column of species id
surveys_df['species_id']
# Out:
# 0         NL
# 1         NL
# 2         DM
# 3         DM
# 4         DM
#         ...
# 35544     AH
# 35545     AH
# 35546     RM
# 35547     DO
# 35548    NaN
# Name: species_id, Length: 35549, dtype: object

# %%
# Checks to see if two columns are printed
surveys_df[['species_id', 'plot_id']]
# Out:
#       species_id  plot_id
# 0             NL        2
# 1             NL        3
# 2             DM        2
# 3             DM        7
# 4             DM        3
# ...          ...      ...
# 35544         AH       15
# 35545         AH       15
# 35546         RM       10
# 35547         DO        7
# 35548        NaN        5
#
# [35549 rows x 2 columns]

# %%
# Create a row from the dataset
surveys_df[0:3]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN

# %%
# Selects the first 5 rows
surveys_df[:5]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Selects the last element
surveys_df[-1:]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 35548     NaN

# %%
# Using the copy method
true_copy_surveys_df = surveys_df.copy()
true_copy_surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Using the = operator

ref_surveys_df = surveys_df
ref_surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# iloc row and column slicing
surveys_df.iloc[0:3, 1:4]
# Out:
#    month  day  year
# 0      7   16  1977
# 1      7   16  1977
# 2      7   16  1977

# %%
# Select all columns for rows of index values 0 and 10
surveys_df.loc[[0, 10], :]
# Out:
#     record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0           1      7   16  1977        2         NL   M             32.0
# 10         11      7   16  1977        5         DS   F             53.0
#
#     weight
# 0      NaN
# 10     NaN

# %%
# Returns the data at index 0
surveys_df.loc[0, ['species_id', 'plot_id', 'weight']]
# Out:
# species_id     NL
# plot_id         2
# weight        NaN
# Name: 0, dtype: object

# %%
# Selects sub data using a specific criteria 
surveys_df[surveys_df.year == 2002]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 33320      33321      1   12  2002        1         DM    M             38.0
# 33321      33322      1   12  2002        1         DO    M             37.0
# 33322      33323      1   12  2002        1         PB    M             28.0
# 33323      33324      1   12  2002        1         AB  NaN              NaN
# 33324      33325      1   12  2002        1         DO    M             35.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 35544      35545     12   31  2002       15         AH  NaN              NaN
# 35545      35546     12   31  2002       15         AH  NaN              NaN
# 35546      35547     12   31  2002       10         RM    F             15.0
# 35547      35548     12   31  2002        7         DO    M             36.0
# 35548      35549     12   31  2002        5        NaN  NaN              NaN
#
#        weight
# 33320    44.0
# ...

# %%
# Defined using a set of criterias (between 1980 and 1985)
surveys_df[(surveys_df.year >= 1980) & (surveys_df.year <= 1985)]
# Out:
#        record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 2270        2271      1   15  1980        8         DO    M             35.0
# 2271        2272      1   15  1980       11         PF    F             16.0
# 2272        2273      1   15  1980       18         DM    F             34.0
# 2273        2274      1   15  1980       11         DM    M             38.0
# 2274        2275      1   15  1980        8         DO    F             33.0
# ...          ...    ...  ...   ...      ...        ...  ...              ...
# 11222      11223     12    8  1985        4         DM    M             36.0
# 11223      11224     12    8  1985       11         DM    M             37.0
# 11224      11225     12    8  1985        7         PE    M             20.0
# 11225      11226     12    8  1985        1         DM    M             38.0
# 11226      11227     12    8  1985       15        NaN  NaN              NaN
#
#        weight
# 2270     53.0
# ...

# %%
# Changes all the weight values to NaN
empty_weights = surveys_df[pd.isnull(surveys_df['weight'])]['weight']
print(empty_weights)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 35530   NaN
# 35543   NaN
# 35544   NaN
# 35545   NaN
# 35548   NaN
# Name: weight, Length: 3266, dtype: float64

# %%
# Checks type of file
type(surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Checks all the types in the dataset
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
# float division
a = 7.2
b = 9

print(a/b)

# Changes a to int and then divide again 
int_a = int(a)

print(int_a/b)
# Out:
# 0.8
# 0.7777777777777778

# %%
# Convert the record_id field from an integer to a float
surveys_df['record_id'] = surveys_df['record_id'].astype('float64')
surveys_df['record_id'].dtype
# Out:
# dtype('float64')

# %%
#Checks the average for a specific column 
surveys_df['weight'].mean()
# Out:
# 42.672428212991356

# %%
df1 = surveys_df.copy()
# Fill all NaN values with 0, and then check the average
df1['weight'] = df1['weight'].fillna(0)
df1['weight'].mean()
# Out:
# 38.751976145601844

# %%
# Removing all the NaN values 
df_na = surveys_df.dropna()

# Writing the new survey data into a new dataset
df_na.to_csv('./surveys_complete.csv', index=False)

# %%
# Reading the survey file without NA values
survey_df = pd.read_csv('./surveys.csv', keep_default_na=False, na_values=[""])

# Read the species file
species_df = pd.read_csv('./species.csv', keep_default_na=False, na_values=[""])

# %%
# Stack the DataFrames on top of each other
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)

# Place the DataFrames side by side
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)

# %%
# Reading the species sub dataset
species_sub = pd.read_csv('./speciesSubset.csv', keep_default_na=False, na_values=[""])


merged_inner = pd.merge(left=survey_sub, right=species_sub, left_on='species_id', right_on='species_id')
# In this case `species_id` is the only column name in  both dataframes, so if we skipped `left_on`
# And `right_on` arguments we would still get the same result

# What's the size of the output data?
merged_inner.shape
merged_inner
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          8      7   16  1977        1         DM   M             37.0
# 6          9      7   16  1977        1         DM   F             34.0
# 7          7      7   16  1977        2         PE   F              NaN
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# 3     NaN   Dipodomys  merriami  Rodent
# 4     NaN   Dipodomys  merriami  Rodent
# 5     NaN   Dipodomys  merriami  Rodent
# ...

# %%
# Using a left merge this time
merged_left = pd.merge(left=survey_sub, right=species_sub, how='left', left_on='species_id', right_on='species_id')
merged_left
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight       genus   species    taxa
# 0     NaN     Neotoma  albigula  Rodent
# 1     NaN     Neotoma  albigula  Rodent
# 2     NaN   Dipodomys  merriami  Rodent
# ...

# %%
# Prints the null values from merged_left

merged_left[ pd.isnull(merged_left.genus) ]
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 5          6      7   16  1977        1         PF   M             14.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight genus species taxa
# 5     NaN   NaN     NaN  NaN
# 9     NaN   NaN     NaN  NaN

# %%
# Declare a list of animals
animals = ['lion', 'tiger', 'crocodile', 'vulture', 'hippo']
print(animals)
# Out:
# ['lion', 'tiger', 'crocodile', 'vulture', 'hippo']

# %%
# Print line by line 
for creature in animals:
    print(creature)
# Out:
# lion
# tiger
# crocodile
# vulture
# hippo

# %%
# Make a new file with the os command
import os

os.mkdir('./yearly_files')

# %%
# Checks for data
os.listdir('.')
# Out:
# ['Lab4.ipynb',
#  'species.csv',
#  'speciesSubset.csv',
#  'surveys.csv',
#  'surveys_complete.csv',
#  'yearly_files']

# %%
# Prints the unique values from surveys_df
surveys_df['year'].unique()
# Out:
# array([1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002], dtype=int64)

# %%
# Generates files for the all the years in the yearly_files folder
for year in surveys_df['year'].unique():
   filename='./yearly_files/surveys' + str(year) + '.csv'
   print(filename)
# Out:
# ./yearly_files/surveys1977.csv
# ./yearly_files/surveys1978.csv
# ./yearly_files/surveys1979.csv
# ./yearly_files/surveys1980.csv
# ./yearly_files/surveys1981.csv
# ./yearly_files/surveys1982.csv
# ./yearly_files/surveys1983.csv
# ./yearly_files/surveys1984.csv
# ./yearly_files/surveys1985.csv
# ./yearly_files/surveys1986.csv
# ./yearly_files/surveys1987.csv
# ./yearly_files/surveys1988.csv
# ./yearly_files/surveys1989.csv
# ./yearly_files/surveys1990.csv
# ./yearly_files/surveys1991.csv
# ./yearly_files/surveys1992.csv
# ./yearly_files/surveys1993.csv
# ./yearly_files/surveys1994.csv
# ./yearly_files/surveys1995.csv
# ./yearly_files/surveys1996.csv
# ./yearly_files/surveys1997.csv
# ./yearly_files/surveys1998.csv
# ./yearly_files/surveys1999.csv
# ./yearly_files/surveys2000.csv
# ./yearly_files/surveys2001.csv
# ./yearly_files/surveys2002.csv

# %%
def this_is_the_function_name(input_argument1, input_argument2):

    # The body of the function is indented
    # This function prints the two arguments to screen
    print('The function arguments are:', input_argument1, input_argument2, '(this is done inside the function!)')

    # And returns their product
    return input_argument1 * input_argument2

# %%
# Checks to see if the above function works fine
product_of_inputs = this_is_the_function_name(2, 5)
print('Their product is:', product_of_inputs, '(this is done outside the function!)')
# Out:
# The function arguments are: 2 5 (this is done inside the function!)
# Their product is: 10 (this is done outside the function!)

# %%
for year in surveys_df['year'].unique():

    # Select data for the year
    surveys_year = surveys_df[surveys_df.year == year]

    # Write the new DataFrame to a CSV file
    filename = './yearly_files/surveys' + str(year) + '.csv'
    surveys_year.to_csv(filename)

# %%
def one_year_csv_writer(this_year, all_data):
    """
    Writes a csv file for data from a given year.

    this_year -- year for which data is extracted
    all_data -- DataFrame with multi-year data
    """

    # Select data for the year
    surveys_year = all_data[all_data.year == this_year]

    # Write the new DataFrame to a csv file
    filename = './yearly_files/function_surveys' + str(this_year) + '.csv'
    surveys_year.to_csv(filename)

# %%
# Checks to see if the above function works
one_year_csv_writer(2002, surveys_df)

# %%
def yearly_data_csv_writer(start_year, end_year, all_data):
    """
    Writes separate CSV files for each year of data.

    start_year -- the first year of data we want
    end_year -- the last year of data we want
    all_data -- DataFrame with multi-year data
    """

    # "end_year" is the last year of data we want to pull, so we loop to end_year+1
    for year in range(start_year, end_year+1):
        one_year_csv_writer(year, all_data)

# %%
# Create CSV files
yearly_data_csv_writer(1977, 2002, surveys_df)

# %%
def yearly_data_arg_test(all_data, start_year=1977, end_year=2002):
    """
    Modified from yearly_data_csv_writer to test default argument values!

    start_year -- the first year of data we want (default 1977)
    end_year -- the last year of data we want (default 2002)
    all_data -- DataFrame with multi-year data
    """

    return start_year, end_year


start, end = yearly_data_arg_test(surveys_df, 1988, 1993)
print('Both optional arguments:\t', start, end)

start, end = yearly_data_arg_test(surveys_df)
print('Default values:\t\t\t', start, end)
# Out:
# Both optional arguments:	 1988 1993
# Default values:			 1977 2002

# %%
def yearly_data_arg_test(all_data, start_year=None, end_year=None):
    """
    Modified from yearly_data_csv_writer to test default argument values!

    all_data -- DataFrame with multi-year data
    start_year -- the first year of data we want, Check all_data! (default None)
    end_year -- the last year of data we want; Check all_data! (default None)
    """

    if start_year is None:
        start_year = min(all_data.year)
    if end_year is None:
        end_year = max(all_data.year)

    return start_year, end_year


start, end = yearly_data_arg_test(surveys_df, 1988, 1993)
print('Both optional arguments:\t', start, end)

start, end = yearly_data_arg_test(surveys_df)
print('Default values:\t\t\t', start, end)
# Out:
# Both optional arguments:	 1988 1993
# Default values:			 1977 2002

# %%
a = 5

if a<0:  # Meets first condition?

    # if a IS less than zero
    print('a is a negative number')

elif a>0:  # Did not meet first condition. meets second condition?

    # if a ISN'T less than zero and IS more than zero
    print('a is a positive number')

else:  # Met neither condition

    # if a ISN'T less than zero and ISN'T more than zero
    print('a must be zero!')
# Out:
# a is a positive number

# %%
# Checks the start and end date for our datasets
start, end = yearly_data_arg_test(surveys_df)
print('Default values:\t\t\t', start, end)

start, end = yearly_data_arg_test(surveys_df, 1988, 1993)
print('No keywords:\t\t\t', start, end)

start, end = yearly_data_arg_test(surveys_df, start_year=1988, end_year=1993)
print('Both keywords, in order:\t', start, end)

start, end = yearly_data_arg_test(surveys_df, end_year=1993, start_year=1988)
print('Both keywords, flipped:\t\t', start, end)

start, end = yearly_data_arg_test(surveys_df, start_year=1988)
print('One keyword, default end:\t', start, end)

start, end = yearly_data_arg_test(surveys_df, end_year=1993)
print('One keyword, default start:\t', start, end)
# Out:
# Default values:			 1977 2002
# No keywords:			 1988 1993
# Both keywords, in order:	 1988 1993
# Both keywords, flipped:		 1988 1993
# One keyword, default end:	 1988 2002
# One keyword, default start:	 1977 1993

# %%
# imported plotnine
import plotnine as p9

surveys_complete = pd.read_csv('./surveys_complete.csv')

# %%
# prints a p9 plot

(p9.ggplot(data=surveys_complete))
# Out:
# <ggplot: (190008204689)>

# %%
# Define a p9 plot with columns 

# Create
surveys_plot = p9.ggplot(data=surveys_complete,
                         mapping=p9.aes(x='weight', y='hindfoot_length'))

# Draw the plot
surveys_plot + p9.geom_point()
# Out:
# <ggplot: (190008309501)>

# %%
# Change alpha to 0.1

surveys_plot + p9.geom_point(alpha=0.1)
# Out:
# <ggplot: (190008328521)>

# %%
#Adding the color blue

surveys_plot + p9.geom_point(alpha=0.1, color='blue')
# Out:
# <ggplot: (190008377007)>

# %%
# maps the species id to the color as well as add it as log function
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
)
# Out:
# <ggplot: (190008579834)>

# %%
# Increase the size of the plots
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight', y='hindfoot_length', color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.xlab("Weight (g)")
    + p9.scale_x_log10()
    + p9.theme_bw()
    + p9.theme(text=p9.element_text(size=16))
)
# Out:
# <ggplot: (190013562679)>

# %%
# Creating a boxplot now

(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_boxplot()
)
# Out:
# <ggplot: (190014070875)>

# %%
# Adding jitter and color effects
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='species_id',
                          y='weight'))
    + p9.geom_jitter(alpha=0.2)
    + p9.geom_boxplot(alpha=0.)
)
# Out:
# <ggplot: (190013500916)>

# %%
# Shows yearly count for all species
yearly_counts = surveys_complete.groupby(['year', 'species_id'])['species_id'].count()
yearly_counts
# Out:
# year  species_id
# 1977  DM            181
#       DO             12
#       DS             29
#       OL              1
#       OX              2
#                    ...
# 2002  PP            375
#       RM             20
#       RO              7
#       SF              5
#       SH              9
# Name: species_id, Length: 332, dtype: int64

# %%
# Facetting
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("sex")
)
# Out:
# <ggplot: (190019315773)>

# %%
# Print multple plots on the same screen

(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='weight',
                          y='hindfoot_length',
                          color='species_id'))
    + p9.geom_point(alpha=0.1)
    + p9.facet_wrap("plot_id")
)
# Out:
# <ggplot: (190019503065)>

# %%
# plotting a geom bar 
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
)
# Out:
# <ggplot: (190019288013)>

# %%
# rotate x-axis labels to make them prettier 
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + p9.theme_bw()
    + p9.theme(axis_text_x = p9.element_text(angle=90))
)
# Out:
# <ggplot: (190014127258)>

# %%
# Same thing as above but custom theme
my_custom_theme = p9.theme(axis_text_x = p9.element_text(color="grey", size=10,
                                                         angle=90, hjust=.5),
                           axis_text_y = p9.element_text(color="grey", size=10))
(p9.ggplot(data=surveys_complete,
           mapping=p9.aes(x='factor(year)'))
    + p9.geom_bar()
    + my_custom_theme
)
# Out:
# <ggplot: (190008549837)>
